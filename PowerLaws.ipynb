# %%
import pandas as pd
import os
import lightgbm as lgb

# %%
train = pd.read_csv("consumption_train.csv")
test = pd.read_csv("cold_start_test.csv")
meta = pd.read_csv("meta.csv")
submission_format = pd.read_csv("submission_format.csv")

# %%
train = train.set_index("_id")
test = test.set_index("_id")
#train.dtypes

# %%
train.head()
# Out:
#      series_id            timestamp    consumption  temperature
# _id
# 0       103088  2014-12-24 00:00:00  101842.233424          NaN
# 1       103088  2014-12-24 01:00:00  105878.048906          NaN
# 2       103088  2014-12-24 02:00:00   91619.105008          NaN
# 3       103088  2014-12-24 03:00:00   94473.706203          NaN
# 4       103088  2014-12-24 04:00:00   96976.755526          NaN

# %%
test.head()
# Out:
#      series_id            timestamp   consumption  temperature
# _id
# 0       102781  2013-02-27 00:00:00  15295.740389        17.00
# 1       102781  2013-02-27 01:00:00  15163.209562        18.25
# 2       102781  2013-02-27 02:00:00  15022.264079        18.00
# 3       102781  2013-02-27 03:00:00  15370.420458        17.00
# 4       102781  2013-02-27 04:00:00  15303.103213        16.90

# %%
train_meta = train.join(meta.set_index("series_id"), on="series_id")
test_meta = test.join(meta.set_index("series_id"), on="series_id")

# %%
train_meta.dtypes
# Out:
# series_id                 int64
# timestamp                object
# consumption             float64
# temperature             float64
# surface                  object
# base_temperature         object
# monday_is_day_off          bool
# tuesday_is_day_off         bool
# wednesday_is_day_off       bool
# thursday_is_day_off        bool
# friday_is_day_off          bool
# saturday_is_day_off        bool
# sunday_is_day_off          bool
# dtype: object

# %%
# surface definition we put an order to all of them 
surfaces = {'xx-small' : 0,'x-small' : 1,'small' :2,'medium' : 3,'large' :4,'x-large':5, 'xx-large':6}
train_meta["order_surface"] = train_meta['surface'].apply(lambda x : surfaces.get(x,-1))
test_meta["order_surface"] = test_meta['surface'].apply(lambda x : surfaces.get(x,-1))

# %%
base_temperatures = {"low":-1, "high": 1}
train_meta["order_base_temperature"] = train_meta['base_temperature'].apply(lambda x : base_temperatures.get(x,-1))
test_meta["order_base_temperature"] = test_meta['base_temperature'].apply(lambda x : base_temperatures.get(x,-1))

# %%
train_meta["timestamp_typed"] = train_meta.timestamp.apply(lambda x: pd.to_datetime(x))

# %%
test_meta["timestamp_typed"] = test_meta.timestamp.apply(lambda x: pd.to_datetime(x))

# %%
train_meta['year'] = train_meta.timestamp_typed.apply(lambda x : x.year)
train_meta['month'] = train_meta.timestamp_typed.apply(lambda x : x.month)
train_meta['day'] = train_meta.timestamp_typed.apply(lambda x : x.day)
train_meta['hours'] = train_meta.timestamp_typed.apply(lambda x : x.hour)

# %%
d = """monday_is_day_off
tuesday_is_day_off         
wednesday_is_day_off       
thursday_is_day_off        
friday_is_day_off          
saturday_is_day_off        
sunday_is_day_off""".split()

# %%
for i in d:
    train_meta[i] = train_meta[i].apply(lambda x : 1 if x else 0)
    test_meta[i] = test_meta[i].apply(lambda x : 1 if x else 0)

# %%
test_meta['year'] = test_meta.timestamp_typed.apply(lambda x : x.year)
test_meta['month'] = test_meta.timestamp_typed.apply(lambda x : x.month)
test_meta['day'] = test_meta.timestamp_typed.apply(lambda x : x.day)
test_meta['hours'] = test_meta.timestamp_typed.apply(lambda x : x.hour)

# %%
train_meta.columns
# Out:
# Index(['series_id', 'timestamp', 'consumption', 'temperature', 'surface',
#        'base_temperature', 'monday_is_day_off', 'tuesday_is_day_off',
#        'wednesday_is_day_off', 'thursday_is_day_off', 'friday_is_day_off',
#        'saturday_is_day_off', 'sunday_is_day_off', 'order_surface',
#        'order_base_temperature', 'timestamp_typed', 'year', 'month', 'day',
#        'hours'],
#       dtype='object')

# %%
y_train = train_meta["consumption"]
X_train = train_meta.drop(['series_id', 'timestamp','surface', 'temperature','consumption',"base_temperature",
                          "timestamp_typed"],axis=1)

# %%
feature_name = list(X_train.columns.values)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression_l1',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

# %%
lgb_train = lgb.Dataset(X_train, y_train, free_raw_data=False)

# %%
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=1000,
                valid_sets=lgb_train,  # eval training data
                feature_name=feature_name)
# Out:
# [1]	training's l1: 88115.5
# [2]	training's l1: 87022.6
# [3]	training's l1: 85968.5
# [4]	training's l1: 85020.4
# [5]	training's l1: 84116.3
# [6]	training's l1: 83328.7
# [7]	training's l1: 82608.9
# [8]	training's l1: 81906
# [9]	training's l1: 81375.1
# [10]	training's l1: 80878.5
# [11]	training's l1: 80514.3
# [12]	training's l1: 80188.8
# [13]	training's l1: 79780.8
# [14]	training's l1: 79629.4
# [15]	training's l1: 79260.2
# [16]	training's l1: 78945.6
# [17]	training's l1: 78498.9
# [18]	training's l1: 78277
# [19]	training's l1: 77867.8
# [20]	training's l1: 77622
# [21]	training's l1: 77345.6
# [22]	training's l1: 76980.2
# [23]	training's l1: 76647.7
# [24]	training's l1: 76431.9
# [25]	training's l1: 76208.2
# [26]	training's l1: 76135.7
# [27]	training's l1: 75811.9
# [28]	training's l1: 75607.3
# [29]	training's l1: 75462.5
# [30]	training's l1: 75396.9
# [31]	training's l1: 75234.4
# [32]	training's l1: 75100.2
# [33]	training's l1: 74941.2
# [34]	training's l1: 74763.7
# [35]	training's l1: 74659.3
# [36]	training's l1: 74485.4
# [37]	training's l1: 74377.3
# [38]	training's l1: 74246.1
# [39]	training's l1: 74162.9
# [40]	training's l1: 74110.6
# [41]	training's l1: 74018.7
# [42]	training's l1: 73948.8
# [43]	training's l1: 73866.4
# [44]	training's l1: 73787
# [45]	training's l1: 73742.1
# [46]	training's l1: 73683.2
# [47]	training's l1: 73640
# [48]	training's l1: 73596.6
# [49]	training's l1: 73400.5
# [50]	training's l1: 73339.5
# [51]	training's l1: 73272
# [52]	training's l1: 73136.6
# [53]	training's l1: 73089.5
# [54]	training's l1: 73017.1
# [55]	training's l1: 72811.2
# [56]	training's l1: 72782.5
# [57]	training's l1: 72746.2
# [58]	training's l1: 72626.4
# [59]	training's l1: 72604
# [60]	training's l1: 72572.6
# [61]	training's l1: 72441.3
# [62]	training's l1: 72407
# [63]	training's l1: 72387.8
# [64]	training's l1: 72258.5
# [65]	training's l1: 72240.3
# [66]	training's l1: 72169.3
# [547]	training's l1: 66194
# [548]	training's l1: 66186
# [549]	training's l1: 66183
# [550]	training's l1: 66177.5
# [551]	training's l1: 66174.1
# [552]	training's l1: 66170.9
# [553]	training's l1: 66150.7
# [554]	training's l1: 66142.4
# [555]	training's l1: 66135
# [556]	training's l1: 66127
# [557]	training's l1: 66125.4
# [558]	training's l1: 66117.8
# [559]	training's l1: 66116.8
# [560]	training's l1: 66115.2
# [561]	training's l1: 66097.5
# [562]	training's l1: 66082.5
# [563]	training's l1: 66080
# [564]	training's l1: 66078.1
# [565]	training's l1: 66076.2
# [566]	training's l1: 66074.4
# [567]	training's l1: 66072.7
# [568]	training's l1: 66070.9
# [569]	training's l1: 66067.4
# [570]	training's l1: 66065.2
# [571]	training's l1: 66055.1
# [572]	training's l1: 66054.1
# [573]	training's l1: 66053.1
# [574]	training's l1: 66047.9
# [575]	training's l1: 66047.3
# [576]	training's l1: 66037.9
# [577]	training's l1: 66017.6
# [578]	training's l1: 66014.4
# [579]	training's l1: 66009.8
# [580]	training's l1: 66009.2
# [581]	training's l1: 66007.9
# [582]	training's l1: 66006.4
# [583]	training's l1: 66004.3
# [584]	training's l1: 65997.9
# [585]	training's l1: 65997.4
# [586]	training's l1: 65970.4
# [587]	training's l1: 65970
# [588]	training's l1: 65951.8
# [589]	training's l1: 65949.7
# [590]	training's l1: 65949
# [591]	training's l1: 65942.6
# [592]	training's l1: 65936.6
# [593]	training's l1: 65934.1
# [594]	training's l1: 65930.9
# [595]	training's l1: 65926.3
# [596]	training's l1: 65925.6
# [597]	training's l1: 65925.1
# [598]	training's l1: 65919
# [599]	training's l1: 65918
# [600]	training's l1: 65912.9
# [601]	training's l1: 65906.7
# [602]	training's l1: 65885.3
# [603]	training's l1: 65866.6
# [604]	training's l1: 65850.6
# [605]	training's l1: 65840.9
# [606]	training's l1: 65839.6
# [607]	training's l1: 65825.6
# [608]	training's l1: 65813.6
# [609]	training's l1: 65803.4
# [610]	training's l1: 65800.4
# [611]	training's l1: 65797.5
# [612]	training's l1: 65793.3
# [613]	training's l1: 65781.8
# [614]	training's l1: 65777.8
# [615]	training's l1: 65773.4
# [616]	training's l1: 65769.3
# [617]	training's l1: 65768.2
# [618]	training's l1: 65747.6
# [619]	training's l1: 65743
# [620]	training's l1: 65738
# [621]	training's l1: 65733.2
# [622]	training's l1: 65729.2
# [623]	training's l1: 65724.7
# [624]	training's l1: 65719.6
# [625]	training's l1: 65719
# [626]	training's l1: 65714.5
# [627]	training's l1: 65703.8
# [628]	training's l1: 65694.8
# [629]	training's l1: 65693.4
# [630]	training's l1: 65687.9
# [631]	training's l1: 65686.4
# [632]	training's l1: 65681.6
# [633]	training's l1: 65677.8
# [634]	training's l1: 65665.9
# [635]	training's l1: 65664
# [636]	training's l1: 65660.2
# [637]	training's l1: 65658.3
# [638]	training's l1: 65656.3
# [639]	training's l1: 65654.1
# [640]	training's l1: 65646.2
# [641]	training's l1: 65630.4
# [642]	training's l1: 65620.2
# [643]	training's l1: 65610.7
# [644]	training's l1: 65607.5
# [645]	training's l1: 65606.3
# [646]	training's l1: 65596.5
# [647]	training's l1: 65586.1
# [648]	training's l1: 65576.5
# [649]	training's l1: 65572.5
# [650]	training's l1: 65565.2
# [651]	training's l1: 65563
# [652]	training's l1: 65561.7
# [653]	training's l1: 65560.4
# [654]	training's l1: 65559.1
# [655]	training's l1: 65557.5
# [656]	training's l1: 65557.1
# [657]	training's l1: 65545.5
# [658]	training's l1: 65536.6
# [659]	training's l1: 65534
# [660]	training's l1: 65521.3
# [661]	training's l1: 65519.9
# [662]	training's l1: 65511.1
# [663]	training's l1: 65510
# [664]	training's l1: 65501.8
# [665]	training's l1: 65494.3
# [666]	training's l1: 65486.4
# [667]	training's l1: 65481.5
# [668]	training's l1: 65481.2
# [669]	training's l1: 65468.8
# [670]	training's l1: 65448.7
# [671]	training's l1: 65447.5
# [672]	training's l1: 65445.9
# [673]	training's l1: 65444.7
# [674]	training's l1: 65443.2
# [675]	training's l1: 65441.5
# [676]	training's l1: 65439.4
# [677]	training's l1: 65435.9
# [678]	training's l1: 65428.6
# [679]	training's l1: 65427.6
# [680]	training's l1: 65424.9
# [681]	training's l1: 65424.3
# [682]	training's l1: 65422.5
# [683]	training's l1: 65415.7
# [684]	training's l1: 65412.6
# [685]	training's l1: 65407.8
# [686]	training's l1: 65405.2
# [687]	training's l1: 65403.3
# [688]	training's l1: 65402.3
# [689]	training's l1: 65400.7
# [690]	training's l1: 65400.2
# [691]	training's l1: 65398.6
# [692]	training's l1: 65397.6
# [693]	training's l1: 65395.6
# [694]	training's l1: 65394.2
# [695]	training's l1: 65385.9
# [696]	training's l1: 65380.7
# [697]	training's l1: 65379.5
# [698]	training's l1: 65377.1
# [699]	training's l1: 65372.7
# [700]	training's l1: 65369.6
# [701]	training's l1: 65368.8
# [702]	training's l1: 65368.5
# [703]	training's l1: 65367.9
# [704]	training's l1: 65367.2
# [705]	training's l1: 65366.4
# [706]	training's l1: 65363.5
# [707]	training's l1: 65360.9
# [708]	training's l1: 65358.7
# [709]	training's l1: 65356.4
# [710]	training's l1: 65351.3
# [711]	training's l1: 65345.4
# [712]	training's l1: 65340.3
# [713]	training's l1: 65325.7
# [714]	training's l1: 65325.4
# [715]	training's l1: 65323.5
# [716]	training's l1: 65319.5
# [717]	training's l1: 65312.8
# [718]	training's l1: 65309.3
# [719]	training's l1: 65305.5
# [720]	training's l1: 65302
# [721]	training's l1: 65298.7
# [722]	training's l1: 65297.9
# [723]	training's l1: 65295.4
# [724]	training's l1: 65292.7
# [725]	training's l1: 65284
# [726]	training's l1: 65266
# [727]	training's l1: 65256.5
# [728]	training's l1: 65239.4
# [729]	training's l1: 65234.1
# [730]	training's l1: 65230.5
# [731]	training's l1: 65226.8
# [732]	training's l1: 65218.5
# [733]	training's l1: 65213.4
# [734]	training's l1: 65209.1
# [735]	training's l1: 65206.7
# [736]	training's l1: 65206.3
# [737]	training's l1: 65205.8
# [738]	training's l1: 65205.5
# [739]	training's l1: 65202.1
# [740]	training's l1: 65195.8
# [741]	training's l1: 65188.2
# [742]	training's l1: 65186.3
# [743]	training's l1: 65185.1
# [744]	training's l1: 65183.2
# [745]	training's l1: 65181.3
# [746]	training's l1: 65180.1
# [747]	training's l1: 65179.3
# [748]	training's l1: 65178.2
# [749]	training's l1: 65177.4
# [750]	training's l1: 65170.8
# [751]	training's l1: 65169.1
# [752]	training's l1: 65166
# [753]	training's l1: 65165.3
# [754]	training's l1: 65164.7
# [755]	training's l1: 65160.4
# [756]	training's l1: 65156
# [757]	training's l1: 65150.4
# [758]	training's l1: 65148.3
# [759]	training's l1: 65147.5
# [760]	training's l1: 65138.2
# [761]	training's l1: 65137.8
# [762]	training's l1: 65126.5
# [763]	training's l1: 65110.5
# [764]	training's l1: 65109.9
# [765]	training's l1: 65096.8
# [766]	training's l1: 65096.2
# [767]	training's l1: 65095.6
# [768]	training's l1: 65094.8
# [769]	training's l1: 65093.5
# [770]	training's l1: 65091.5
# [771]	training's l1: 65077.3
# [772]	training's l1: 65064.5
# [773]	training's l1: 65052.9
# [774]	training's l1: 65050.8
# [775]	training's l1: 65049.9
# [776]	training's l1: 65040.6
# [777]	training's l1: 65033.8
# [778]	training's l1: 65030.7
# [779]	training's l1: 65028.1
# [780]	training's l1: 65027.4
# [781]	training's l1: 65025.9
# [782]	training's l1: 65023.9
# [783]	training's l1: 65022.5
# [784]	training's l1: 65021.8
# [785]	training's l1: 65020.5
# [786]	training's l1: 65017.9
# [787]	training's l1: 65014.3
# [788]	training's l1: 65009
# [789]	training's l1: 65008
# [790]	training's l1: 65005.2
# [791]	training's l1: 65000.2
# [792]	training's l1: 64988.8
# [793]	training's l1: 64986.8
# [794]	training's l1: 64982.9
# [795]	training's l1: 64978.4
# [796]	training's l1: 64977.1
# [797]	training's l1: 64976
# [798]	training's l1: 64974.9
# [799]	training's l1: 64972.1
# [800]	training's l1: 64966.9
# [801]	training's l1: 64965.9
# [802]	training's l1: 64945.1
# [803]	training's l1: 64943.7
# [804]	training's l1: 64938.1
# [805]	training's l1: 64936.6
# [806]	training's l1: 64934.9
# [807]	training's l1: 64934.5
# [808]	training's l1: 64934.4
# [809]	training's l1: 64933.8
# [810]	training's l1: 64933.6
# [811]	training's l1: 64933.2
# [812]	training's l1: 64930.5
# [813]	training's l1: 64929.7
# [814]	training's l1: 64928.8
# [815]	training's l1: 64925.4
# [816]	training's l1: 64916.9
# [817]	training's l1: 64916.3
# [818]	training's l1: 64915.4
# [819]	training's l1: 64911.9
# [820]	training's l1: 64910.1
# [821]	training's l1: 64904.8
# [822]	training's l1: 64903.2
# [823]	training's l1: 64899.2
# [824]	training's l1: 64888.6
# [825]	training's l1: 64885.5
# [826]	training's l1: 64878.5
# [827]	training's l1: 64876.3
# [828]	training's l1: 64873.9
# [829]	training's l1: 64873.1
# [830]	training's l1: 64864.7
# [831]	training's l1: 64863.6
# [832]	training's l1: 64852.4
# [833]	training's l1: 64838.3
# [834]	training's l1: 64831.5
# [835]	training's l1: 64827.4
# [836]	training's l1: 64821.1
# [837]	training's l1: 64812.7
# [838]	training's l1: 64808.7
# [839]	training's l1: 64804.7
# [840]	training's l1: 64803.6
# [841]	training's l1: 64799.5
# [842]	training's l1: 64798.3
# [843]	training's l1: 64791.9
# [844]	training's l1: 64791
# [845]	training's l1: 64789.6
# [846]	training's l1: 64784.9
# [847]	training's l1: 64784.3
# [848]	training's l1: 64783.8
# [849]	training's l1: 64783.2
# [850]	training's l1: 64782.7
# [851]	training's l1: 64780.9
# [852]	training's l1: 64779.5
# [853]	training's l1: 64769.1
# [854]	training's l1: 64763.9
# [855]	training's l1: 64762.1
# [856]	training's l1: 64760.3
# [857]	training's l1: 64759.7
# [858]	training's l1: 64759.5
# [859]	training's l1: 64759.3
# [860]	training's l1: 64758.6
# [861]	training's l1: 64755.1
# [862]	training's l1: 64754.9
# [863]	training's l1: 64754.5
# [864]	training's l1: 64754.2
# [865]	training's l1: 64753.8
# [866]	training's l1: 64751.9
# [867]	training's l1: 64750.3
# [868]	training's l1: 64749
# [869]	training's l1: 64744.3
# [870]	training's l1: 64741.9
# [871]	training's l1: 64739.6
# [872]	training's l1: 64736.5
# [873]	training's l1: 64734
# [874]	training's l1: 64731.9
# [875]	training's l1: 64729.1
# [876]	training's l1: 64727.8
# [877]	training's l1: 64726.1
# [878]	training's l1: 64720.2
# [879]	training's l1: 64718.4
# [880]	training's l1: 64717.9
# [881]	training's l1: 64712.2
# [882]	training's l1: 64710.3
# [883]	training's l1: 64710
# [884]	training's l1: 64705.2
# [885]	training's l1: 64704.9
# [886]	training's l1: 64704.4
# [887]	training's l1: 64704.1
# [888]	training's l1: 64703.8
# [889]	training's l1: 64703.5
# [890]	training's l1: 64700.2
# [891]	training's l1: 64699.6
# [892]	training's l1: 64699
# [893]	training's l1: 64698.5
# [894]	training's l1: 64697.8
# [895]	training's l1: 64697.4
# [896]	training's l1: 64695.8
# [897]	training's l1: 64692.8
# [898]	training's l1: 64691.5
# [899]	training's l1: 64690.4
# [900]	training's l1: 64689.4
# [901]	training's l1: 64684.8
# [902]	training's l1: 64684.5
# [903]	training's l1: 64683.5
# [904]	training's l1: 64681.2
# [905]	training's l1: 64680.9
# [906]	training's l1: 64680.7
# [907]	training's l1: 64680
# [908]	training's l1: 64679.7
# [909]	training's l1: 64673
# [910]	training's l1: 64672.4
# [911]	training's l1: 64671.6
# [912]	training's l1: 64671.2
# [913]	training's l1: 64671.1
# [914]	training's l1: 64670.6
# [915]	training's l1: 64670.2
# [916]	training's l1: 64669.6
# [917]	training's l1: 64669.1
# [918]	training's l1: 64668.5
# [919]	training's l1: 64667.9
# [920]	training's l1: 64667.8
# [921]	training's l1: 64664.3
# [922]	training's l1: 64663.3
# [923]	training's l1: 64656.3
# [924]	training's l1: 64655.5
# [925]	training's l1: 64654.9
# [926]	training's l1: 64654.6
# [927]	training's l1: 64654.4
# [928]	training's l1: 64653.8
# [929]	training's l1: 64653.6
# [930]	training's l1: 64647.9
# [931]	training's l1: 64646.2
# [932]	training's l1: 64645.7
# [933]	training's l1: 64644.3
# [934]	training's l1: 64643.9
# [935]	training's l1: 64643.5
# [936]	training's l1: 64638.6
# [937]	training's l1: 64636.9
# [938]	training's l1: 64635.2
# [939]	training's l1: 64627.9
# [940]	training's l1: 64627.1
# [941]	training's l1: 64626.6
# [942]	training's l1: 64625
# [943]	training's l1: 64623.2
# [944]	training's l1: 64621.3
# [945]	training's l1: 64620.8
# [946]	training's l1: 64618.5
# [947]	training's l1: 64618.2
# [948]	training's l1: 64618
# [949]	training's l1: 64610.2
# [950]	training's l1: 64609.9
# [951]	training's l1: 64605.9
# [952]	training's l1: 64603.1
# [953]	training's l1: 64602.5
# [954]	training's l1: 64601.6
# [955]	training's l1: 64601.1
# [956]	training's l1: 64594.8
# [957]	training's l1: 64593.1
# [958]	training's l1: 64591.3
# [959]	training's l1: 64590.1
# [960]	training's l1: 64589.9
# [961]	training's l1: 64586.1
# [962]	training's l1: 64584.1
# [963]	training's l1: 64582.6
# [964]	training's l1: 64582
# [965]	training's l1: 64577.2
# [966]	training's l1: 64573
# [967]	training's l1: 64568.7
# [968]	training's l1: 64564.7
# [969]	training's l1: 64562.8
# [970]	training's l1: 64562.1
# [971]	training's l1: 64557.5
# [972]	training's l1: 64555.7
# [973]	training's l1: 64544.3
# [974]	training's l1: 64536.4
# [975]	training's l1: 64530.9
# [976]	training's l1: 64530.5
# [977]	training's l1: 64528.7
# [978]	training's l1: 64527
# [979]	training's l1: 64522.9
# [980]	training's l1: 64522.6
# [981]	training's l1: 64520.3
# [982]	training's l1: 64518.2
# [983]	training's l1: 64516.6
# [984]	training's l1: 64514.2
# [985]	training's l1: 64512.5
# [986]	training's l1: 64511.4
# [987]	training's l1: 64511.3
# [988]	training's l1: 64510.9
# [989]	training's l1: 64510.6
# [990]	training's l1: 64509.5
# [991]	training's l1: 64507.9
# [992]	training's l1: 64506.4
# [993]	training's l1: 64505.7
# [994]	training's l1: 64504.2
# [995]	training's l1: 64503.8
# [996]	training's l1: 64503
# [997]	training's l1: 64497.6
# [998]	training's l1: 64497
# [999]	training's l1: 64492.3
# [1000]	training's l1: 64491.2

# %%
sub = pd.merge(test_meta, submission_format,  how='right', left_on=['series_id','timestamp'], right_on = ['series_id','timestamp'])

# %%
sub.dtypes
# Out:
# series_id                          int64
# timestamp                         object
# consumption_x                    float64
# temperature_x                    float64
# surface                           object
# base_temperature                  object
# monday_is_day_off                float64
# tuesday_is_day_off               float64
# wednesday_is_day_off             float64
# thursday_is_day_off              float64
# friday_is_day_off                float64
# saturday_is_day_off              float64
# sunday_is_day_off                float64
# order_surface                    float64
# order_base_temperature           float64
# timestamp_typed           datetime64[ns]
# year                             float64
# month                            float64
# day                              float64
# hours                            float64
# pred_id                            int64
# temperature_y                    float64
# consumption_y                    float64
# prediction_window                 object
# dtype: object

# %%
data = sub[feature_name]
predicts = gbm.predict(data)

# %%
submission_format.consumption = predicts

# %%
submission_format.to_csv("submission.csv", index=False)
